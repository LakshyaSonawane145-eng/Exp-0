# %% [markdown]
#  Name : Lakshya Sonawane
#  Exp 0 : Introduction to Python

# %%
#PRN:25070123068
print("Name: Lakshya Sonawane")
# Out:
# Name: Lakshya Sonawane

# %%
print(2)
# Out:
# 2

# %%
print([1, 2 ,5])
# Out:
# [1, 2, 5]

# %%
a = 2
b = [1,2,5]
c = "Lakshya Sonawane"
print(a,b,c,sep="\n")
# Out:
# 2
# [1, 2, 5]
# Lakshya Sonawane
